# %% [markdown]
# Q1. Describe the differences between text and binary files in a single paragraph.
#
# Text files store data in human-readable format, using ASCII or Unicode characters. Binary files store data in a format that is not human-readable, using a series of 0s and 1s. Text files are typically used for storing data that needs to be easily readable by humans, such as configuration files, log files, and plain text documents. Binary files are typically used for storing data that needs to be stored efficiently, such as images, audio files, and executable programs.
#
# Q2. What are some scenarios where using text files will be the better option? When would you like to use binary files instead of text files?
#
# Text files are a better option when you need to store data that needs to be easily readable by humans. For example, you would use a text file to store the configuration settings for a software program, so that the user can easily read and modify them. Binary files are a better option when you need to store data that needs to be stored efficiently. For example, you would use a binary file to store an image or audio file, so that it takes up as little space as possible on your hard drive.
#
# Q3. What are some of the issues with using binary operations to read and write a Python integer directly to disc?
#
# One issue with using binary operations to read and write a Python integer directly to disc is that you may not be able to read the integer back in if you are using a different platform or operating system. This is because the way that integers are represented in binary format can vary from platform to platform. Another issue is that binary operations can be slower than using text operations, especially if you are reading or writing large amounts of data.
#
# Q4. Describe a benefit of using the with keyword instead of explicitly opening a file.
#
# The with keyword is a Python construct that allows you to open a file and automatically close it when you are finished with it. This can help to prevent errors and memory leaks, as you are sure that the file will be closed properly even if an exception is raised. Additionally, the with keyword can help to improve the readability of your code, as it makes it clear that you are only using the file for a specific block of code.
#
# Q5. Does Python have the trailing newline while reading a line of text? Does Python append a newline when you write a line of text?
#
# By default, Python does not have the trailing newline while reading a line of text. This means that if you read a line of text from a file, the last character will not be a newline character. However, you can use the readlines() method to read the entire line of text, including the newline character. Python will append a newline character when you write a line of text to a file. This means that if you write a line of text to a file, the last character will be a newline character.
#
# Q6. What file operations enable for random-access operation?
#
# The file operations that enable for random-access operation are seek() and tell(). The seek() method allows you to move the file pointer to a specific location in the file. The tell() method returns the current position of the file pointer. By using these two methods, you can read or write data to any location in the file, regardless of where the file pointer is currently positioned.
#
# Q7. When do you think you'll use the struct package the most?
#
# I think I will use the struct package the most when I need to read or write data in a specific format, such as a binary format. The struct package provides a set of functions that allow you to pack and unpack data into a specific format. This can be useful for reading or writing data that is not stored in a standard format, such as data that is generated by a specific piece of hardware or software.
#
# Q8. When is pickling the best option?
#
# Pickling is the best option when you need to save a Python object to a file and then be able to load it back into a Python program at a later time. Pickling can be used to save any type of Python object, including lists, dictionaries, and classes.
#
# Q9. When will it be best to use the shelve package?
#
# The shelve package is a good option when you need to store a Python object in a file and then be able to access it quickly. The shelve package uses a hash table to store the objects, which makes it very fast to access the objects. Additionally, the shelve package can be used to store multiple objects in a single file, which can save space.
#
# Q10. What is a special restriction when using the shelve package, as opposed to using other data dictionaries?
#
# The shelve package has a special restriction that the keys in the dictionary must be strings. This means that you cannot use other data types, such as integers or floats, as keys. This restriction is due to the way that the shelve package stores the objects in a file. The keys are used to index the objects in the file, and strings are the only data type that can be used as an index.
#
# Other data dictionaries, such as dict and collections.OrderedDict, do not have this restriction. This means that you can use any data type as a key in these dictionaries.
