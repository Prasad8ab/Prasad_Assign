# %% [markdown]
# 1. Compare and contrast the float and Decimal classes' benefits and drawbacks.
# 2. Decimal('1.200') and Decimal('1.2') are two objects to consider. In what sense are these the same object? Are these just two ways of representing the exact same value, or do they correspond to different internal states?
# 3. What happens if the equality of Decimal('1.200') and Decimal('1.2') is checked?
# 4. Why is it preferable to start a Decimal object with a string rather than a floating-point value?
# 5. In an arithmetic phrase, how simple is it to combine Decimal objects with integers?
# 6. Can Decimal objects and floating-point values be combined easily?
# 7. Using the Fraction class but not the Decimal class, give an example of a quantity that can be expressed with absolute precision.
# 8. Describe a quantity that can be accurately expressed by the Decimal or Fraction classes but not by a floating-point value.
# 9. Consider the following two fraction objects: Fraction(1, 2) and Fraction(1, 2). (5, 10). Is the internal state of these two objects the same? Why do you think that is?
# 10. How do the Fraction class and the integer type (int) relate to each other? Containment or inheritance?
#
#
# Ans:
#
# (1) Compare and contrast the float and Decimal classes' benefits and drawbacks.
#
# Float
# Benefits:
# Faster than Decimal
# Smaller memory footprint
# Drawbacks:
# Less precise than Decimal
# Can lose precision when performing calculations
# Decimal
# Benefits:
# More precise than Float
# Can represent all rational numbers
# Less likely to lose precision when performing calculations
# Drawbacks:
# Slower than Float
# Larger memory footprint
# (2) Decimal('1.200') and Decimal('1.2') are two objects to consider. In what sense are these the same object? Are these just two ways of representing the exact same value, or do they correspond to different internal states?
#
# These are two different objects with the same value. They are just two different ways of representing the same value.
# The internal state of these two objects is the same. They both store the value 1.200 as a decimal number.
# (3) What happens if the equality of Decimal('1.200') and Decimal('1.2') is checked?
#
# Checking the equality of Decimal('1.200') and Decimal('1.2') will return True.
# This is because the two objects have the same value. Even though they are represented in different ways, they are both stored as the same decimal number internally.
# (4) Why is it preferable to start a Decimal object with a string rather than a floating-point value?
#
# This is because Decimal objects are more precise than floating-point values. If you start a Decimal object with a floating-point value, there is a chance that the value will be rounded down, which can lead to errors.
# For example, the floating-point value 1.2000000000000002 is actually equal to the decimal value 1.2000000000000002, but if you start a Decimal object with the floating-point value, the value will be rounded down to 1.2.
# (5) In an arithmetic phrase, how simple is it to combine Decimal objects with integers?
#
# It is simple to combine Decimal objects with integers in an arithmetic phrase.
# Decimal objects and integers can be combined using the usual arithmetic operators (+, -, *, /). The results of these operations will be Decimal objects.
# For example, the expression Decimal('1.2') + 1 will evaluate to the Decimal object 2.2.
# (6) Can Decimal objects and floating-point values be combined easily?
#
# Yes, Decimal objects and floating-point values can be combined easily.
# Decimal objects and floating-point values can be combined using the usual arithmetic operators (+, -, *, /). The results of these operations will be Decimal objects.
# For example, the expression Decimal('1.2') + 1.2 will evaluate to the Decimal object 2.4.
# (7) Using the Fraction class but not the Decimal class, give an example of a quantity that can be expressed with absolute precision.
#
# The fraction Fraction(1, 2) represents the number 0.5, which can be represented exactly as a fraction.
#  (8) Describe a quantity that can be accurately expressed by the Decimal or Fraction classes but not by a floating-point value.
# * The number 1/10 is a non-terminating, non-repeating decimal, which means that it cannot be accurately represented by a floating-point value. However, it can be accurately represented by the Decimal or Fraction classes.
#
# (9) Consider the following two fraction objects: Fraction(1, 2) and Fraction(1, 2). (5, 10). Is the internal state of these two objects the same? Why do you think that is?
#
# Yes, the internal state of these two objects is the same. They both store the same numerator and denominator, which are 1 and 2.
# The reason why the internal state of these two objects is the same is because the Fraction class is immutable. Once a Fraction object is created, its numerator and denominator cannot be changed.
#
# (10) The Fraction class and the integer type (int) are not related to each other
# The Fraction class is a separate class from the int type. They do not inherit from each other, and they do not have any direct relationship.
